# %% [markdown]
# ## DATA EXPLORATION USING PANDAS

# %% [markdown]
# #### This dataset is downloaded from the Kaggle dataset website and used it to do some basic data exploration using pandas. This dataset contains the passengers namelist whom sunk in the Titanic ship on 14 April 1912.

# %%
import pandas as pd

# %% [markdown]
# #### To perform the operations we need to import a library, so here pandas library is imported locally as pd

# %%
Titanic=pd.read_csv('D:/Downloads/Titanic.csv')

# %% [markdown]
# #### Use pd.read_csv function to read the dataset in to Jupyter Notebook

# %%
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# #### To view the read dataset, use the dataset name Titantic

# %%
Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# #### The First five observations of the dataset

# %%
Titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# #### The last five observations of dataset

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# #### To know the variable and its datatype

# %%
Titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# #### Basic Statistics

# %%
Titanic.shape
# Out:
# (418, 12)

# %% [markdown]
# #### 418 Variables and 12 Observations

# %%
Titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### Observations list in dataset

# %%
Titanic.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %% [markdown]
# #### RangeIndex starts from 0 and ends in 418

# %%
Titanic.sort_values(['Age'],ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# ..           ...       ...     ...                                      ...
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
# 413         1305         0       3                       Spector, Mr. Woolf
# 416         1308         0       3                      Ware, Mr. Frederick
# 417         1309         0       3                 Peter, Master. Michael J
#
# ...

# %% [markdown]
# #### Dataset is arranged ascending according to the Age variable

# %%
Titanic['Age'].value_counts()
# Out:
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 76.0     1
# 28.5     1
# 22.5     1
# 62.0     1
# 38.5     1
# Name: Age, Length: 79, dtype: int64

# %% [markdown]
# #### Count of Age in dataset

# %%
Titanic.drop_duplicates(inplace=True)

# %%
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# #### No duplicates found in the dataset

# %%
Titanic_subset=Titanic[['Name','Age','Sex']]

# %%
Titanic_subset
# Out:
#                                              Name   Age     Sex
# 0                                Kelly, Mr. James  34.5    male
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0  female
# 2                       Myles, Mr. Thomas Francis  62.0    male
# 3                                Wirz, Mr. Albert  27.0    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0  female
# ..                                            ...   ...     ...
# 413                            Spector, Mr. Woolf   NaN    male
# 414                  Oliva y Ocana, Dona. Fermina  39.0  female
# 415                  Saether, Mr. Simon Sivertsen  38.5    male
# 416                           Ware, Mr. Frederick   NaN    male
# 417                      Peter, Master. Michael J   NaN    male
#
# [418 rows x 3 columns]

# %% [markdown]
# #### Column subset dataset created

# %%
Titanic_row=Titanic[Titanic['Fare']>10]

# %%
Titanic_row
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 7            899         0       2
# 9            901         0       3
# 11           903         0       1
# 12           904         1       1
# ..           ...       ...     ...
# 407         1299         0       1
# 409         1301         1       3
# 411         1303         1       1
# 414         1306         1       1
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 7                       Caldwell, Mr. Albert Francis    male  26.0      1
# 9                            Davies, Mr. John Samuel    male  21.0      2
# 11                        Jones, Mr. Charles Cresson    male  46.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [markdown]
# #### Row subset dataset created

# %%
Titanic_index=Titanic.set_index("PassengerId")

# %%
Titanic_index
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# #### Changing the default index position

# %%
Titanic_index=Titanic.reset_index()

# %%
Titanic_index
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0          892         0       3
# 1        1          893         1       3
# 2        2          894         0       2
# 3        3          895         0       3
# 4        4          896         1       3
# ..     ...          ...       ...     ...
# 413    413         1305         0       3
# 414    414         1306         1       1
# 415    415         1307         0       3
# 416    416         1308         0       3
# 417    417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# ...

# %% [markdown]
# #### Resetting the index position to default

# %%
Titanic_loc=Titanic.loc[(Titanic.Age>=32)&(Titanic.Sex=="female")]

# %%
Titanic_loc
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 14           906         1       1
# 19           911         1       3
# 24           916         1       1
# 32           924         1       3
# 44           936         1       1
# 48           940         1       1
# 49           941         1       3
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 77           969         1       1
# 96           988         1       1
# 100          992         1       1
# 112         1004         1       1
# 114         1006         1       1
# 122         1014         1       1
# 141         1033         1       1
# 153         1045         1       3
# 178         1070         1       2
# 179         1071         1       1
# 206         1098         1       3
# 208         1100         1       1
# 213         1105         1       2
# 214         1106         1       3
# ...

# %% [markdown]
# #### Locating a variable in dataset

# %%
Titanic_iloc=Titanic.iloc[0:5,1:6]

# %%
Titanic_iloc
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 0         0       3                              Kelly, Mr. James    male
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2         0       2                     Myles, Mr. Thomas Francis    male
# 3         0       3                              Wirz, Mr. Albert    male
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age
# 0  34.5
# 1  47.0
# 2  62.0
# 3  27.0
# 4  22.0

# %% [markdown]
# #### Locating data using integer position

# %%
Titanic_agg=Titanic.groupby("Sex")['Age'].mean()

# %%
Titanic_agg
# Out:
# Sex
# female    30.272362
# male      30.272732
# Name: Age, dtype: float64

# %% [markdown]
# #### Groupby aggregate function

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 42.5+ KB

# %%
Titanic['PassengerId']=Titanic['PassengerId'].astype('object')

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    object
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 42.5+ KB

# %% [markdown]
# #### Datatype has been changed
